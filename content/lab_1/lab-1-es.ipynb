# %% [markdown]
# ![Notebook_Header_01.png](data:image/png;base64,...)

# %% [markdown]
# # Laboratorio 1: Introducción a Qiskit 1.0

# %% [markdown]
# # Tabla de contenido
# - **[Introducción](##Introducción)**
# - **[Parte I: estados Qiskit, lo nuevo y lo antiguo](#Parte-I:-Qiskit-states,-lo-nuevo-y-lo-antiguo)**
#     - **[Ejercicio 1: Crear y dibujar un circuito de estado Bell](#Ejercicio1)**
#     - **[Ejercicio 2: Utilizar Sampler.run](#Ejercicio2)**
#     - **[Ejercicio 3: Crear y dibujar un circuito de estado W](#Ejercicio2)**
# - **[Parte II: VQE con Qiskit 1.0](#Part-II:-VQE-with-Qiskit-1.0)**
#     - **[Ejercicio 4: Crear a parametrizar un circuito como ansatz](#Ejercicio4)**
#     - **[Ejercicio 5: Transpilar a circuitos ISA](#Ejercicio5)**
#     - **[Ejercicio 6: Definiendo la función de costes](#Ejercicio6)**
#     - **[Ejercicio 7: QiskitRuntimeService V2 primitivas, modo de testeo local y sesiones, una primera vista](#Ejercicio7)**

# %% [markdown]
# ## Configuración

# %%
### Instale Qiskit, si es necesario

# %pip install qiskit[visualization]==1.0.2
# %pip install qiskit_aer
# %pip install qiskit_ibm_runtime
# %pip install matplotlib
# %pip install pylatexenc
# %pip install prototype-zne
# %pip install git+https://github.com/qiskit-community/Quantum-Challenge-Grader.git
# Out:
# Requirement already satisfied: qiskit==1.0.2 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit[visualization]==1.0.2) (1.0.2)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (0.14.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (1.12.1)
# Requirement already satisfied: dill>=0.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (4.12.1)
# Requirement already satisfied: symengine>=0.11 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (0.11.0)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit[visualization]==1.0.2) (3.9.0)
# Requirement already satisfied: pydot in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit[visualization]==1.0.2) (2.0.0)
# Requirement already satisfied: Pillow>=4.2.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit[visualization]==1.0.2) (10.3.0)
# Requirement already satisfied: pylatexenc>=1.4 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit[visualization]==1.0.2) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit[visualization]==1.0.2) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\renat\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.0->qiskit==1.0.2->qiskit[visualization]==1.0.2) (1.16.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from seaborn>=0.9.0->qiskit[visualization]==1.0.2) (2.2.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from stevedore>=3.0.0->qiskit==1.0.2->qiskit[visualization]==1.0.2) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.3->qiskit==1.0.2->qiskit[visualization]==1.0.2) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]==1.0.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]==1.0.2) (2024.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit_aer in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (0.14.2)
# Requirement already satisfied: qiskit>=0.45.2 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_aer) (1.0.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_aer) (1.13.1)
# Requirement already satisfied: psutil>=5 in c:\users\renat\appdata\roaming\python\python312\site-packages (from qiskit_aer) (5.9.8)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (0.14.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (1.12.1)
# Requirement already satisfied: dill>=0.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from qiskit>=0.45.2->qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (4.12.1)
# Requirement already satisfied: symengine>=0.11 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\renat\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.0->qiskit>=0.45.2->qiskit_aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from stevedore>=3.0.0->qiskit>=0.45.2->qiskit_aer) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.3->qiskit>=0.45.2->qiskit_aer) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit_ibm_runtime in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (0.23.0)
# Requirement already satisfied: requests>=2.19 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_ibm_runtime) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_ibm_runtime) (1.2.0)
# Requirement already satisfied: numpy>=1.13 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_ibm_runtime) (1.26.4)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_ibm_runtime) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from qiskit_ibm_runtime) (2.9.0.post0)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_ibm_runtime) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_ibm_runtime) (0.53.7)
# Requirement already satisfied: pydantic in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_ibm_runtime) (2.7.3)
# Requirement already satisfied: qiskit>=1.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit_ibm_runtime) (1.0.2)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.19.2 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (3.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\renat\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.14.2)
# Requirement already satisfied: scipy>=1.5 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (1.12.1)
# Requirement already satisfied: dill>=0.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (4.12.1)
# Requirement already satisfied: symengine>=0.11 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (2024.6.2)
# Requirement already satisfied: cryptography>=1.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (42.0.8)
# Requirement already satisfied: pyspnego>=0.1.6 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (0.10.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from pydantic->qiskit_ibm_runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from pydantic->qiskit_ibm_runtime) (2.18.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (2.8.0)
# Requirement already satisfied: sspilib>=0.1.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from pyspnego>=0.1.6->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (0.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.0.0->qiskit_ibm_runtime) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.3->qiskit>=1.0.0->qiskit_ibm_runtime) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.22)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\renat\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\renat\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pylatexenc in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (2.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: prototype-zne in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (1.3.1)
# Requirement already satisfied: qiskit>=0.45.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from prototype-zne) (1.0.2)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.1->prototype-zne) (0.14.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.1->prototype-zne) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.1->prototype-zne) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.1->prototype-zne) (1.12.1)
# Requirement already satisfied: dill>=0.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.1->prototype-zne) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from qiskit>=0.45.1->prototype-zne) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.1->prototype-zne) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.1->prototype-zne) (4.12.1)
# Requirement already satisfied: symengine>=0.11 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qiskit>=0.45.1->prototype-zne) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\renat\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.0->qiskit>=0.45.1->prototype-zne) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from stevedore>=3.0.0->qiskit>=0.45.1->prototype-zne) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.3->qiskit>=0.45.1->prototype-zne) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/qiskit-community/Quantum-Challenge-Grader.git
#   Cloning https://github.com/qiskit-community/Quantum-Challenge-Grader.git to c:\users\renat\appdata\local\temp\pip-req-build-iam8cvz7
#   Resolved https://github.com/qiskit-community/Quantum-Challenge-Grader.git to commit 9ec0aa6ac3a7ff8650e274e3574ba18e62d1fd41
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: typeguard in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qc_grader==0.18.10) (4.3.0)
# Requirement already satisfied: jsonpickle==3.0.3 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qc_grader==0.18.10) (3.0.3)
# Requirement already satisfied: ipycytoscape in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qc_grader==0.18.10) (1.3.3)
# Requirement already satisfied: plotly in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qc_grader==0.18.10) (5.22.0)
# Requirement already satisfied: networkx==3.2.1 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from qc_grader==0.18.10) (3.2.1)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from ipycytoscape->qc_grader==0.18.10) (8.1.3)
# Requirement already satisfied: spectate>=1.0.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from ipycytoscape->qc_grader==0.18.10) (1.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from plotly->qc_grader==0.18.10) (8.3.0)
# Requirement already satisfied: packaging in c:\users\renat\appdata\roaming\python\python312\site-packages (from plotly->qc_grader==0.18.10) (24.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from typeguard->qc_grader==0.18.10) (4.12.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\renat\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (3.0.11)
# Requirement already satisfied: decorator in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (3.0.46)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (0.6.3)
# Requirement already satisfied: colorama in c:\users\renat\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\renat\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\renat\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\renat\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\renat\appdata\roaming\python\python312\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->ipycytoscape->qc_grader==0.18.10) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/qiskit-community/Quantum-Challenge-Grader.git 'C:\Users\renat\AppData\Local\Temp\pip-req-build-iam8cvz7'

# %%
### Guarde el token API

# %set_env QXToken=122d96e2ea683466f8d0bf4d1f5ebe5060756c7fbfdda7efe974c0311970d49c52bb898f1efc4cd035a0b5c182adb5309168c8d486b9220336085ca7e121e2f7

# Asegúrese de que no haya espacio entre el signo igual
# y el comienzo de su token
# Out:
# env: QXToken=122d96e2ea683466f8d0bf4d1f5ebe5060756c7fbfdda7efe974c0311970d49c52bb898f1efc4cd035a0b5c182adb5309168c8d486b9220336085ca7e121e2f7

# %%
# Importaciones

import numpy as np
from typing import List, Callable
from scipy.optimize import minimize
from scipy.optimize._optimize import OptimizeResult
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, Operator, SparsePauliOp
from qiskit.primitives import StatevectorSampler, PrimitiveJob
from qiskit.circuit.library import TwoLocal
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime.fake_provider import FakeSherbrooke
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator

# %%
# Configure el grader
from qc_grader.challenges.iqc_2024 import (
    grade_lab1_ex1,
    grade_lab1_ex2,
    grade_lab1_ex3,
    grade_lab1_ex4,
    grade_lab1_ex5,
    grade_lab1_ex6,
    grade_lab1_ex7,
)

# %% [markdown]
# ## Introducción

# %% [markdown]
# Bienvenid@s a nuestro primer desafío! El primer desafío está diseñado para introducir las nuevas capacidades y funciones de Qiskit 1.0.
#
# Los siguientes desafíos tendrán un énfasis más profundo en estas capacidades e introducirán conceptos más complejos.
# Durante este desafío reaprenderán como diseñar circuitos cuánticos con Qiskit y como implementar algoritmos de optimización utilizando un VQE (Variational Quantum Eigensolver).
# Estos dos objetivos se llevarán a cabo en dos secciones:
#
# 1) Estados cuánticos con Qiskit, lo nuevo y lo antiguo
# 2) VQE con Qiskit 1.0
#
# ¡Empecemos!

# %% [markdown]
# ## Parte I: Estados cuánticos con Qiskit, lo nuevo y lo antiguo

# %% [markdown]
# <a id="exercise1"></a>
# <div class="alert alert-block alert-success">
#
# <b> Ejercicio 1: Crear y dibujar un circuito de estado Bell</b>
#
# Los circuitos Bell son circuitos específicos que generan estados de Bell, o pares EPR, una tipo de vectores de base entrelazados y normalizados. En otras palabras, son los circuitos que utilizamos para generar estados entrelazados, un ingrediente clave en las recetas cuánticas.
#
# Existen 4 estados de Bell. Puede aprender sobre cada uno en la [página conceptos básicos de información cuántica](https://learning.quantum.ibm.com/course/basics-of-quantum-information/multiple-systems#bell-states)
#
#
# **Su tarea:** Construya un circuito que genere el estado Bell $| \psi ^- \rangle$.
#
# </div>

# %%
# Build a circuit to form a psi-minus Bell state
# Apply gates to the provided QuantumCircuit, qc

qc = QuantumCircuit(2)

### Write your code below here ###
qc.x(1)
qc.h(0)
qc.z(0)
qc.z(1)
qc.cx(0 ,1)


### Don't change any code past this line ###
qc.measure_all()
qc.draw('mpl')

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Pista:** El estado $| \psi ^- \rangle$ utiliza una sola puerta Z y una sola puerta X, las cuales ocurren después del CNOT.
#
# </div>

# %%
# Envíe su respuesta usando el siguiente código

grade_lab1_ex1(qc) # Tipo de resultado esperado: QuantumCircuit
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# Para observar el estado entrelazado resultante que produce este circuito, ejecutaremos nuestro circuito varias veces y recopilaremos estadísticas sobre las medidas finales del cúbit. Ese es el objetivo del próximo ejercicio.

# %% [markdown]
# <a id="exercise2"></a>
# <a name="exercise2"></a>
# <div class="alert alert-block alert-success">
#
# <b> Ejercicio 2: Utilizar Sampler.run</b>
#
# La primitiva [Qiskit Sampler](https://docs.quantum.ibm.com/api/qiskit/qiskit.primitives.StatevectorSampler) ([más información sobre Primitivas aquí](https://docs.quantum.ibm.com/run/primitives-get-started)) resulta en el tipo de salida especificada. Esto nos permite muestrear de manera eficiente estados cuánticos ejecutando circuitos cuánticos y proporcionando distribuciones de probabilidad de los estados cuánticos.
#
# **Su tarea:** Utilize Qiskit StatevectorSampler para obtener las cuentas resultantes de nuestro circuito.
#
# </div>

# %%
qc.measure_all()

### Write your code below here ###


sampler = StatevectorSampler()
pub = (qc)
job_sampler = sampler.run([pub], shots=256)


### Don't change any code past this line ###

result_sampler = job_sampler.result()
counts_sampler = result_sampler[0].data.meas.get_counts()

print(counts_sampler)
# Out:
# {'01': 134, '10': 122}

# %%
# Envíe su respuesta usando el siguiente código

grade_lab1_ex2(job_sampler) # Tipo de resultado esperado: PrimitiveJob
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %%
plot_histogram(counts_sampler)

# %% [markdown]
# El histograma muestra una probabilidad aproximadamente uniforme de encontrar nuestros cúbits en los estados `01` y `10`, lo que sugiere que el entrelazamiento se realizó como esperabamos.

# %% [markdown]
# <a id="exercise3"></a>
# <a name="exercise3"></a>
# <div class="alert alert-block alert-success">
#
# <b> Ejercicio 3: Crear y dibujar un circuito de estado W</b>
#
# A continuación, desarrollaremos un circuito un poco más complicado. De manera similar al circuito Bell que produce estados Bell, los circuitos W producen estados W. Aunque los estados Bell entrelazan dos cúbits, los estados W entrelazan tres cúbits.
# Para construir nuestro estado W, seguiremos 6 sencillos pasos:
#
# 1. Inicialice un circuito de 3 cúbits
# 2. Realice una rotación Ry en nuestro cúbit. Los detalles de esta operación son proporcionados.
# 3. Agregue una puerta hadamard controlada en el cúbit 1, con el cúbit de control 0
# 4. Agregue una puerta CNOT con el cúbit de control 1 y el cúbit de destino 2
# 5. Agregue una puerta CNOT con cúbit de control 0 y cúbit de destino 1
# 6. Agregue una puerta X en el cúbit 0
#
# **Su tarea:** Sigua los pasos para construir el circuito del estado W.
#
# </div>

# %%
# Step 1
qc = QuantumCircuit(3)

# Step 2 (provided)
qc.ry(1.91063324, 0)

# Add steps 3-6 below
qc.ch(0, 1)
qc.cx(1, 2)
qc.cx(0, 1)
qc.x(0)


### Don't change any code past this line ###
qc.measure_all()
qc.draw('mpl')

# %%
# Envíe su respuesta usando el siguiente código

grade_lab1_ex3(qc) # Tipo de resultado esperado: QuantumCircuit
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# Una vez más, visualicemos nuestros resultados:

# %%
sampler = StatevectorSampler()
pub = (qc)
job_sampler = sampler.run([pub], shots=10000)

result_sampler = job_sampler.result()
counts_sampler = result_sampler[0].data.meas.get_counts()

print(counts_sampler)
# Out:
# {'010': 3280, '001': 3345, '100': 3375}

# %%
plot_histogram(counts_sampler)

# %% [markdown]
# Observamos nuestros recuentos totales distribuidos en tres contenedores de tamaño similar en tres estados, que son los tres estados deseados para la creación exitosa de un estado W. ¡Buen trabajo!
#
# Ahora que tenemos los circuitos básicos, comenzaremos a introducir y desarrollar códigos más complejos con Qiskit 1.0.

# %% [markdown]
# ## Parte II: VQE con Qiskit 1.0
# <a name="pt2"></a>

# %% [markdown]
# El núcleo de este desafío aprovechará Qiskit Runtime y un Variational Quantum Eigensolver (VQE). Usaremos Qiskit Runtime Estimator para calcular los resultados esperados y Qiskit Runtime Sessions para facilitar la ejecución de un algoritmo VQE. El desafío se basa en el código que el físico experimental e investigador de IBM Quantum Nick Bronn creó para la [serie de videos Coding with Qiskit Runtime](https://www.youtube.com/playlist?list=PLOFEBzvs-VvqAC8DnVoLOzg2bKE4C7ARM), específicamente en el [Episodio 05 Primitivos y sesiones](https://youtu.be/yxuH8eb4MS4?si=e3trSORNjooWlQXu). Implementaremos este código utilizando la versión más reciente de Qiskit 1.0.

# %% [markdown]
# ### Empecemos creando un operador Pauli
# Un operador de Pauli es una matriz que representa un observable de la mecánica cuántica correspondiente a una medida del giro a lo largo de un eje particular (x, y, z). Construyamos uno:

# %%
pauli_op = SparsePauliOp(['ZII', 'IZI', 'IIZ'])
print(pauli_op.to_matrix())
# Out:
# [[ 3.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  1.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j -3.+0.j]]

# %% [markdown]
# ¡Te invitamos a experimentar con varios operadores Pauli y ver qué posibles combinaciones resultantes obtienes!

# %% [markdown]
# ### Configurar y ejecutar un algoritmo VQE

# %% [markdown]
# Ahora comenzaremos a configurar nuestro algoritmo VQE. Los eigensolvers cuánticos variacionales (VQE) son algoritmos híbridos que utilizan técnicas cuánticas y clásicas para encontrar el estado fundamental de un sistema físico determinado. Se utilizan a menudo en química cuántica y problemas de optimización, y son candidatos prometedores para algoritmos híbridos en dispositivos ruidosos a corto plazo.

# %% [markdown]
# Los VQE se caracterizan por el uso de un algoritmo de optimización clásico para mejorar iterativamente una solución de prueba parametrizada, llamada "ansatz". El objetivo es resolver el estado fundamental de un hamiltoniano dado representado como una combinación lineal de términos de Pauli.

# %% [markdown]
# La ejecución de un algoritmo VQE requiere estos tres pasos:
#
# 1. Configuración del hamiltoniano y ansatz (especificación del problema)
# 2. Implementación del estimador Qiskit Runtime
# 3. Agregar el optimizador clásico y ejecutar nuestro programa.
#
# Nosotros seguiremos estos pasos.

# %% [markdown]
# <a id="exercise4"></a>
# <a name="exercise4"></a>
# <div class="alert alert-block alert-success">
#
# <b> Ejercicio 4: Crear a parametrizar un circuito como ansatz</b>
#
# Nuestra primera tarea será configurar nuestro ansatz, o una solución inicial, que utilizaremos como guía para perfeccionar y/o comparar nuestros resultados.
#
# Para poder llevar esto acabo usaremos el circuito `TwoLocal` de Qiskit. `TwoLocal` es un circuito prediseñado que puede usarse para preparar funciones de onda de prueba para algoritmos cuánticos variacionales o circuitos de clasificación para aprendizaje automático. Los circuitos TwoLocal son circuitos parametrizados que constan de capas de rotación alternas y capas de entrelazamiento. Puede encontrar más información sobre ellos en la [documentación de Qiskit](https://docs.quantum.ibm.com/api/qiskit/circuit_library).
#
# **Su tarea:** Configure un circuito TwoLocal de 3 cúbits usando rotaciones [Ry](https://docs.quantum.ibm.com/api/qiskit/qiskit.circuit.library.RYGate) y [Rz](https://docs.quantum.ibm.com/api/qiskit/qiskit.circuit.library.RZGate). El entrelazamiento debe configurarse al máximo y los bloques de entrelazamiento deben usar la puerta Cz. Asegúrese de configurar `reps=1` e `insert_barriers=True`.
#
# </div>

# %%
num_qubits = 3
rotation_blocks = ['ry', 'rz']
entanglement_blocks = 'cz'
entanglement = 'full'

ansatz = TwoLocal(num_qubits=num_qubits, 
                  rotation_blocks=rotation_blocks, 
                  entanglement_blocks=entanglement_blocks, 
                  entanglement=entanglement, 
                  reps=1, 
                  insert_barriers=True)


### Don't change any code past this line ###
ansatz.decompose().draw('mpl')

# %%
# Envíe Su respuesta usando el siguiente código

grade_lab1_ex4(num_qubits, rotation_blocks, entanglement_blocks, entanglement) # Expected result type: int, List[str], str, str
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# En la figura anterior vemos que nuestro circuito ansatz está definido por un vector de parámetros θ, con un número total de parámetros:

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 12

# %% [markdown]
# <a id="exercise5"></a>
# <a name="exercise5"></a>
# <div class="alert alert-block alert-success">
#
# <b> Ejercicio 5: Transpilar a circuitos ISA </b>
#
# En este ejemplo usaremos [FakeSherbrooke](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.fake_provider.FakeSherbrooke), un backend falso (simulado) de 127 cúbits, utilizado para probar el transpilador y otras funcionalidades orientadas al backend.
#
# Los administradores de pases preestablecidos son los administradores de pases predeterminados utilizados por la función `transpile()`. `transpile()` proporciona un método conveniente y simple para construir un objeto `PassManager` independiente que refleja lo que hace la función transpile al optimizar y transformar un circuito cuántico para su ejecución en un backend específico.
#
# **Su tarea:** Defina el administrador de pases. Consulte la [documentación de Qiskit](https://docs.quantum.ibm.com/api/qiskit/0.42/qiskit.transpiler.preset_passmanagers.generate_preset_pass_manager) para obtener más información.
#
# </div>

# %%
backend_answer = FakeSherbrooke()
optimization_level_answer = 1
pm = generate_preset_pass_manager(backend=backend_answer,optimization_level=optimization_level_answer)
isa_circuit = pm.run(ansatz)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Consejo: ¡Asegúrate de estar utilizando el backend correcto! </b>
#
# El clasificador fue diseñado teniendo en cuenta **FakeSherbrooke** y, por lo tanto, espera un mapa de 127 cúbits. Si utiliza otro backend, puede tener problemas.
#
#
# </div>

# %%
# Envíe su respuesta usando el siguiente código

grade_lab1_ex5(isa_circuit) # Tipo de resultado esperado: QuansumCircuit
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# Con la versión más reciente de Qiskit Runtime, todos los circuitos enviados a un backend deben cumplir con las limitaciones del backend deseado. Se considera que dichos circuitos están escritos de manera compatible con la arquitectura del backend en uso ([Instruction Set Architecture - ISA](https://www.ibm.com/quantum/blog/isa-circuits?social_post=sf187802680&sf187802680=1)), es decir, con el conjunto de instrucciones que el dispositivo puede entender y ejecutar. Estas restricciones de destino se definen por factores como las puertas básicas nativas del dispositivo, su conectividad de cúbit y, cuando sea relevante, otras especificaciones relacionadas con la sincronización de la máquina.
# Para visualizar nuestros circuitos ISA podemos ejecutar:

# %%
isa_circuit.draw('mpl', idle_wires=False,)

# %% [markdown]
# Después de la transpilación, el circuito solo contiene las puertas básicas nativas del backend. Para obtener más detalles sobre los circuitos ISA, consulte estos recursos del equipo de IBM:
#
# - [What are ISA circuits?](https://www.ibm.com/quantum/blog/isa-circuits)
# - [Understanding the new ISA circuits requirement](https://docs.quantum.ibm.com/announcements/news/2024-05-06-ISA-circuit-requirement#understanding-the-new-isa-circuits-requirement)
#
# A continuación ejecuté el siguiente código para definir nuestro hamiltoniano y luego pasar al Ejercicio 6.

# %%
# Defina nuestro Hamiltoniano
hamiltonian_isa = pauli_op.apply_layout(layout=isa_circuit.layout)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Consejo: ¡Para los dos ejercicios siguientes, asegúrese de estar trabajando con Qiskit 1.0.2! </b>
#
# Puede descargar esta versión usando: **!pip install qiskit==1.0.2**
#
#
# </div>

# %% [markdown]
# <a id="exercise5"></a>
# <a name="exercise5"></a>
# <div class="alert alert-block alert-success">
#
# <b> Ejercicio 6: Definiendo la función de costes </b>
#
# Como muchos problemas de optimización clásicos, la solución a un problema VQE se puede formular como la minimización de una función de coste. La función de coste de nuestro VQE es simple: ¡la energía!
#
# **Su tarea:** Defina una función de coste utilizando Qiskit Runtime Estimator para encontrar la energía para un estado parametrizado determinado y nuestro hamiltoniano.
#
# </div>

# %%
def cost_func(params, ansatz, hamiltonian, estimator, callback_dict):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run([pub]).result()
    energy = result[0].data.evs[0]

    callback_dict["iters"] += 1
    callback_dict["prev_vector"] = params
    callback_dict["cost_history"].append(energy)


### Don't change any code past this line ###
    print(energy)
    return energy, result

# %%
# Envíe su respuesta usando el siguiente código

grade_lab1_ex6(cost_func) # Tipo de resultado esperado:
# Out:
# [0.68505859]
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# Las funciones callback son una forma estándar para obtener información adicional sobre el estado de un algoritmo iterativo (como VQE). Sin embargo, es posible hacer mucho más que esto. Aquí, usamos un objeto mutable (diccionario) para almacenar el vector resultante en cada iteración de nuestro algoritmo, en caso de que necesitemos reiniciar la rutina debido a un fallo o devolver el número de otra iteración.

# %%
callback_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %% [markdown]
# ### Usando el optimizador clásico

# %% [markdown]
# Ahora podemos usar un optimizador clásico de nuestra elección para minimizar la función de coste.
# En el hardware cuántico real, la elección del optimizador es importante, ya que no todos los optimizadores manejan igualmente bien los entornos ruidosos de funciones de coste. Aquí podemos usar rutinas SciPy.
#
# Para empezar, especificamos un conjunto inicial aleatorio de parámetros:

# %%
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([3.66010668, 1.76041096, 0.00692471, 4.54918328, 6.04032977,
#        4.98503759, 2.46615815, 4.76960811, 0.66132307, 0.49620726,
#        0.21713912, 0.66001517])

# %% [markdown]
# <a id="exercise7"></a>
# <a name="exercise7"></a>
# <div class="alert alert-block alert-success">
#
# <b> Ejercicio 7: QiskitRuntimeService V2 primitivas, modo de testeo local y sesiones, una primera vista </b>
#
#
# A continuación, utilizaremos el nuevo QiskitRuntimeService [primitivas V2](https://docs.quantum.ibm.com/api/migration-guides/v2-primitives): [EstimatorV2](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) y [SamplerV2](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.SamplerV2).
#
# La nueva interfaz del **Estimator** nos permite especificar un único circuito, múltiples observables y conjuntos de parámetros para ese circuito, de modo que se puedan especificar de manera eficaz barridos sobre conjuntos de valores de parámetros y observables. Anteriormente, teníamos que especificar el mismo circuito varias veces para que coincidiera con el tamaño de los datos que se iban a combinar. Además, si bien aún puede usar optimización_level y resilience_level como controles simples, las primitivas V2 brindan una mayor flexibilidad para activar o desactivar métodos individuales de mitigación/supresión de errores, así permitiendo personalizaciones según sus necesidades.
#
# **SamplerV2** es ahora más simple, centrándose en su tarea principal de muestrear el registro cuántico a partir de la ejecución de circuitos cuánticos. SamplerV2 devuelve las muestras, cuyo tipo está definido por el programa, sin pesos. Los datos de salida también están separados por los nombres de los registros de salida definidos por el programa. Este cambio permite el soporte futuro para circuitos con flujo de control clásico.
#
# También utilizaremos el [modo de prueba local de Qiskit 1.0](https://docs.quantum.ibm.com/verify/local-testing-mode). El modo de prueba local (disponible con qiskit-ibm-runtime 0.22.0 o posterior) se puede utilizar para ayudar a desarrollar y probar programas antes de ajustarlos y enviarlos a hardware cuántico real.
#
# **Su tarea:** Después de usar el modo de prueba local para verificar su programa, todo lo que necesita hacer es cambiar el nombre del backend para ejecutarlo en un sistema IBM Quantum.
#
# </div>

# %%
### Select a Backend
## Use FakeSherbrooke to simulate with noise that matches closer to the real experiment. This will run slower.
## Use AerSimulator to simulate without noise to quickly iterate. This will run faster.

#backend = FakeSherbrooke()
backend = AerSimulator()

# ### Don't change any code past this line ###

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method="cobyla",
        options={'maxiter': 30})
# Out:
# 0.646484375
# 0.78173828125
# 1.16943359375
# 0.63916015625
# 0.59716796875
# 0.69140625
# 0.5478515625
# 0.71240234375
# 0.62158203125
# 0.015625
# 0.00537109375
# 0.0576171875
# 0.00927734375
# 0.1279296875
# -0.0478515625
# -0.4853515625
# 0.1240234375
# -0.087890625
# -0.736328125
# -0.48779296875
# -1.6005859375
# -1.650390625
# -1.24365234375
# -2.43408203125
# -1.80322265625
# -2.4326171875
# -2.60400390625
# -2.61083984375
# -2.82373046875
# -2.83251953125

# %%
# Envíe su respuesta usando el siguiente código

grade_lab1_ex7(res) # Tipo de resultado esperado: OptimizeReSult
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Consejo: aumente `maxiter` si no ve convergencia </b>
#
# Si el coste no converge, aumente el `maxiter` (100 es un número apropiado) y ejecute el Ejemplo 7 de nuevo.
#
# </div>

# %% [markdown]
# Veamos nuestros resultados:

# %%
fig, ax = plt.subplots()
plt.plot(range(callback_dict["iters"]), callback_dict["cost_history"])
plt.xlabel("Iteracion")
plt.ylabel("Coste")
plt.draw()

# %% [markdown]
# 🎉 Como era de esperar, nuestro algoritmo VQE minimizó la energía a lo largo de las iteraciones, hasta alcanzar el estado fundamental. ¡Ahora hemos implementado con éxito un algoritmo VQE utilizando las nuevas funcionalidades Qiskit 1.0!

# %% [markdown]
# ¡Gracias por completar este laboratorio y buena suerte con los siguientes!

# %% [markdown]
# # Información adicional
#
# **Creado por:** James Weaver, María Gragera Garcés
#
# **Supervisado por:** Junye Huang
#
# **Traducido por:** María Gragera Garcés
#
# **Versión:** 1.2.0
